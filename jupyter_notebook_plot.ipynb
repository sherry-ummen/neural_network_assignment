# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

datafile = 'users_elisa.csv'
data = pd.read_csv(datafile, header=0, delimiter=';', decimal=',')

x = data.iloc[:, 5:8].values
y = data.iloc[:, 13:55].values

# Create a figure instance
fig = plt.figure()

# Create an axes instance
ax = fig.add_axes([0,0,3,3])

# Create the boxplot
bp = ax.violinplot(data.iloc[:,4:].values)
plt.show()

# %%
data
# Out:
#            Time  Day  Hour  Rownum  ...  L82948  L88321  L88322  L92673
# 0    1493683200    3     0       1  ...    0.00   44.30   86.66   38.91
# 1    1493686800    3     1       2  ...    0.00   34.85   65.75   28.89
# 2    1493690400    3     2       3  ...    0.00   29.28   54.47   24.12
# 3    1493694000    3     3       4  ...    0.00   24.83   48.81   22.07
# 4    1493697600    3     4       5  ...    0.00   23.36   41.16   19.89
# 5    1493701200    3     5       6  ...    0.00   24.19   41.45   19.81
# 6    1493704800    3     6       7  ...    0.00   32.94   54.36   23.34
# 7    1493708400    3     7       8  ...    0.00   56.35   68.05   32.25
# 8    1493712000    3     8       9  ...    0.00   74.81   81.39   50.68
# 9    1493715600    3     9      10  ...    0.02   74.43   92.68   43.38
# 10   1493719200    3    10      11  ...    0.08   78.15  108.37   43.87
# 11   1493722800    3    11      12  ...    0.10   92.31  118.53   47.58
# 12   1493726400    3    12      13  ...    0.12   93.80  124.51   52.81
# 13   1493730000    3    13      14  ...    0.20   91.51  128.56   49.61
# 14   1493733600    3    14      15  ...    0.22   99.02  122.39   46.38
# 15   1493737200    3    15      16  ...    0.17  104.09  129.00   48.83
# 16   1493740800    3    16      17  ...    0.12  108.62  125.34   47.04
# 17   1493744400    3    17      18  ...    0.02  109.47  125.56   51.65
# 18   1493748000    3    18      19  ...    0.09   96.46  126.74   53.25
# 19   1493751600    3    19      20  ...    0.15   84.50  129.99   47.85
# 20   1493755200    3    20      21  ...    0.04   89.85  137.28   50.31
# 21   1493758800    3    21      22  ...    0.01   87.83  140.23   59.47
# 22   1493762400    3    22      23  ...    0.00   83.13  137.22   63.09
# 23   1493766000    3    23      24  ...    0.01   67.93  118.34   46.61
# 24   1493769600    4     0      25  ...    0.00   49.34   85.64   37.22
# 25   1493773200    4     1      26  ...    0.00   33.61   64.92   28.66
# 26   1493776800    4     2      27  ...    0.00   24.08   50.45   24.90
# 27   1493780400    4     3      28  ...    0.00   23.34   46.09   22.11
# 28   1493784000    4     4      29  ...    0.00   22.09   40.73   17.76
# 29   1493787600    4     5      30  ...    0.00   24.36   46.21   17.87
# ..          ...  ...   ...     ...  ...     ...     ...     ...     ...
# 478  1495414800    2     1     479  ...    0.00   40.51   61.85   26.38
# 479  1495418400    2     2     480  ...    0.00   31.98   48.98   21.53
# 480  1495422000    2     3     481  ...    0.00   28.38   38.78   16.78
# 481  1495425600    2     4     482  ...    0.00   26.67   37.91   18.29
# 482  1495429200    2     5     483  ...    0.00   27.27   41.82   17.88
# 483  1495432800    2     6     484  ...    0.00   38.50   49.64   18.10
# 484  1495436400    2     7     485  ...    0.01   58.43   68.07   29.59
# 485  1495440000    2     8     486  ...    0.08   79.17   84.31   36.58
# 486  1495443600    2     9     487  ...    0.14   81.14   94.82   37.73
# 487  1495447200    2    10     488  ...    0.18   84.96  102.54   37.09
# 488  1495450800    2    11     489  ...    0.22   90.14  113.86   33.84
# 489  1495454400    2    12     490  ...    0.12   92.61  118.45   36.84
# 490  1495458000    2    13     491  ...    0.27   91.47  122.80   33.25
# 491  1495461600    2    14     492  ...    0.18  100.26  118.50   34.31
# 492  1495465200    2    15     493  ...    0.66  108.81  111.59   42.19
# 493  1495468800    2    16     494  ...    1.59  107.83  115.43   46.58
# 494  1495472400    2    17     495  ...    1.01  101.62  115.01   47.90
# 495  1495476000    2    18     496  ...    0.93   88.07  110.57   48.35
# 496  1495479600    2    19     497  ...    0.53   87.14  113.82   48.26
# 497  1495483200    2    20     498  ...    0.14   85.96  116.07   48.28
# 498  1495486800    2    21     499  ...    0.32   80.29  124.63   54.01
# 499  1495490400    2    22     500  ...    0.19   73.07  128.42   50.66
# 500  1495494000    2    23     501  ...    0.09   61.81  104.13   47.91
# 501  1495497600    3     0     502  ...    0.11   53.78   84.99   36.46
# 502  1495501200    3     1     503  ...    0.01   41.18   62.52   28.49
# 503  1495504800    3     2     504  ...    0.00   34.42   50.55   23.39
# 504  1495508400    3     3     505  ...    0.00   28.92   45.85   19.99
# 505  1495512000    3     4     506  ...    0.00   25.50   40.58   16.86
# 506  1495515600    3     5     507  ...    0.00   28.29   42.09   17.63
# 507  1495519200    3     6     508  ...    0.28   38.63   49.32   21.09
#
# [508 rows x 55 columns]

# %%
x
# Out:
# array([[20, 20, 20],
#        [20, 20, 20],
#        [20, 20, 20],
#        ...,
#        [20, 20, 20],
#        [20, 20, 20],
#        [20, 20, 20]])

# %%
y
# Out:
# array([[20.22,  8.38,  0.  , ..., 44.3 , 86.66, 38.91],
#        [15.37,  7.1 ,  0.  , ..., 34.85, 65.75, 28.89],
#        [10.04,  5.97,  0.  , ..., 29.28, 54.47, 24.12],
#        ...,
#        [13.09,  7.65,  0.12, ..., 25.5 , 40.58, 16.86],
#        [14.59,  7.33,  0.53, ..., 28.29, 42.09, 17.63],
#        [15.86,  8.55,  1.77, ..., 38.63, 49.32, 21.09]])
